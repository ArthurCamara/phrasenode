# %%
import pandas as pd

# %%
dataset = pd.read_csv("/Users/acamara/Downloads/safe-environment.tsv", sep="\t", )

# %%
dataset[len(dataset]
# Out:
#     Activity%20theory  Activity theory  \
# 0   Activity%20theory  Activity theory
# 1   Activity%20theory  Activity theory
# 2   Activity%20theory  Activity theory
# 3   Activity%20theory  Activity theory
# 4   Activity%20theory  Activity theory
# 5   Activity%20theory  Activity theory
# 6   Activity%20theory  Activity theory
# 7   Activity%20theory  Activity theory
# 8   Activity%20theory  Activity theory
# 9   Activity%20theory  Activity theory
# 10  Activity%20theory  Activity theory
# 11  Activity%20theory  Activity theory
# 12  Activity%20theory  Activity theory
# 13  Activity%20theory  Activity theory
# 14  Activity%20theory  Activity theory
# 15  Activity%20theory  Activity theory
# 16  Activity%20theory  Activity theory
# 17  Activity%20theory  Activity theory
# 18  Activity%20theory  Activity theory
# 19  Activity%20theory  Activity theory
#
#     12ed92a163c727c76eb02b0272e45f2d4b4e70b6  \
# 0   1301ad3b52a71dcde7b9cece7ce09e1e52973531
# ...
